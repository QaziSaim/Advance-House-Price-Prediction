# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split,GridSearchCV,StratifiedGroupKFold,KFold
from sklearn.linear_model import Ridge,Lasso,LinearRegression

# %%
data=pd.read_csv('data/X_train.csv')

# %%
plt.figure(figsize=(50,50))

sns.heatmap(data.corr().round(2),annot=True,)
# Out:
# <Axes: >

# %%
# import pandas as pd

# Assuming `data` is your dataframe
# Compute the correlation matrix
correlation_matrix = data.corr()

# Filter only negative correlations
negative_correlation = correlation_matrix[correlation_matrix < 0]

# Optional: Filter for strong negative correlations (e.g., below -0.5)
strong_negative_correlation = negative_correlation[negative_correlation < -0.5]

# Print the result
print("Strong negative correlations:")
print(strong_negative_correlation)
# Out:
# Strong negative correlations:
#                 Id  SalePrice  MSSubClass  MSZoning  LotFrontage  LotArea  \
# Id             NaN        NaN         NaN       NaN          NaN      NaN
# SalePrice      NaN        NaN         NaN       NaN          NaN      NaN
# MSSubClass     NaN        NaN         NaN       NaN          NaN      NaN
# MSZoning       NaN        NaN         NaN       NaN          NaN      NaN
# LotFrontage    NaN        NaN         NaN       NaN          NaN      NaN
# ...             ..        ...         ...       ...          ...      ...
# SaleType       NaN        NaN         NaN       NaN          NaN      NaN
# SaleCondition  NaN        NaN         NaN       NaN          NaN      NaN
# LotFrontagenan NaN        NaN         NaN       NaN          NaN      NaN
# MasVnrAreanan  NaN        NaN         NaN       NaN          NaN      NaN
# GarageYrBltnan NaN        NaN         NaN       NaN          NaN      NaN
#
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(negative_correlation.round(2),annot=True)
# Out:
# <Axes: >
